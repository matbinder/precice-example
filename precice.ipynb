# %% [markdown]
# # Partitioned heat conduction
# https://github.com/precice/tutorials/tree/master/partitioned-heat-conduction
#
# ## Summary
# We solve a simple heat equation. The domain is partitioned and the coupling is established in a Dirichlet-Neumann fashion.
#
# ## Setup
#
# We solve a partitioned heat equation. For information on the non-partitioned case, please refer to [1, p.37ff]. In this tutorial the computational domain is partitioned and coupled via preCICE. The coupling roughly follows the approach described in [2].
#
# ![Case setup of partitioned-heat-conduction case](images/tutorials-partitioned-heat-conduction-setup.png)
#
# Case setup from [3]. `D` denotes the Dirichlet participant and `N` denotes the Neumann participant.
#
# The heat equation is solved on a rectangular domain `Omega = [0,2] x [0,1]` with given Dirichlet boundary conditions. We split the domain at `x_c = 1` using a straight vertical line, the coupling interface. The left part of the domain will be referred to as the Dirichlet partition and the right part as the Neumann partition. To couple the two participants we use Dirichlet-Neumann coupling. Here, the Dirichlet participant receives Dirichlet boundary conditions (`Temperature`) at the coupling interface and solves the heat equation using these boundary conditions on the left part of the domain. Then the Dirichlet participant computes the resulting heat flux (`Flux`) from the solution and sends it to the Neumann participant. The Neumann participant uses the flux as a Neumann boundary condition to solve the heat equation on the right part of the domain. We then extract the temperature from the solution and send it back to the Dirichlet participant. This establishes the coupling between the two participants.
#
# This simple case allows us to compare the solution for the partitioned case to a known analytical solution (method of manufactures solutions, see [1, p.37ff]). For more usage examples and details, please refer to [3, sect. 4.1].

# %%
from subprocess import Popen, PIPE

# %%
process_1 = Popen(
    [
        "python3", 
        "heat.py", 
        "-d", 
        "--error-tol", 
        "10e-3"
    ], 
    stdout=PIPE, 
    stderr=PIPE, 
    cwd="fenics", 
    universal_newlines=True
)

# %%
process_2 = Popen(
    [
        "python3", 
        "heat.py", 
        "-n", 
        "--error-tol", 
        "10e-3"
    ], 
    stdout=PIPE, 
    stderr=PIPE, 
    cwd="fenics", 
    universal_newlines=True
)

# %%
stdout, stderr = process_1.communicate()

# %%
stdout.split('\n')
# Out:
# ['---[precice] \x1b This is preCICE version 2.3.0',
#  '---[precice] \x1b Revision info: no-info [Git failed/Not a repository]',
#  '---[precice] \x1b Configuration: Debug',
#  '---[precice] \x1b Configuring preCICE with configuration "/home/jovyan/fenics/../precice-config.xml"',
#  '---[precice] \x1b I am participant "Dirichlet"',
#  '---[precice] \x1b Setting up master communication to coupling partner/s',
#  '---[precice] \x1b Masters are connected',
#  '---[precice] \x1b Setting up preliminary slaves communication to coupling partner/s',
#  '---[precice] \x1b Prepare partition for mesh Dirichlet-Mesh',
#  '---[precice] \x1b Gather mesh Dirichlet-Mesh',
#  '---[precice] \x1b Send global mesh Dirichlet-Mesh',
#  '---[precice] \x1b Receive global mesh Neumann-Mesh',
#  '---[precice] \x1b Setting up slaves communication to coupling partner/s',
#  '---[precice] \x1b Slaves are connected',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, write-iteration-checkpoint ',
#  '---[precice] \x1b Compute "read" mapping from mesh "Neumann-Mesh" to mesh "Dirichlet-Mesh".',
#  '---[precice] \x1b Using tree-based preallocation for matrix C',
#  '---[precice] \x1b Using tree-based preallocation for matrix A',
#  '---[precice] \x1b Using rescaling. Solver converged after 5 of 10000 iterations due to sufficient relative convergence. Last residual norm: 2.70042e-13, limits: relative 3.16228e-09 (rtol 1e-09), absolute 1e-50, divergence 3.16228e+30(dtol 1e+30)',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  'output u^0 and u_ref^0',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 4 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 5 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 6 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 7 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 8 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 9 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 1, t = 0.10: L2 error on domain = 7.27e-09',
#  'output u^1 and u_ref^1',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 2, t = 0.20: L2 error on domain = 5.06e-10',
#  'output u^2 and u_ref^2',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 4, time: 0.3 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 3, t = 0.30: L2 error on domain = 4.75e-11',
#  'output u^3 and u_ref^3',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 4, time: 0.3 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 4, time: 0.3 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 5, time: 0.4 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 4, t = 0.40: L2 error on domain = 1.3e-11',
#  'output u^4 and u_ref^4',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 5, time: 0.4 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 5, time: 0.4 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 6, time: 0.5 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 5, t = 0.50: L2 error on domain = 4.83e-11',
#  'output u^5 and u_ref^5',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 6, time: 0.5 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 6, time: 0.5 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 7, time: 0.6 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 6, t = 0.60: L2 error on domain = 8.36e-12',
#  'output u^6 and u_ref^6',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 7, time: 0.6 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 7, time: 0.6 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 8, time: 0.7 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 7, t = 0.70: L2 error on domain = 1.55e-11',
#  'output u^7 and u_ref^7',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 8, time: 0.7 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 8, time: 0.7 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 8, t = 0.80: L2 error on domain = 7.91e-12',
#  'output u^8 and u_ref^8',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 9, t = 0.90: L2 error on domain = 8.19e-12',
#  'output u^9 and u_ref^9',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  'Solving linear variational problem.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 11, time: 1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: no, time-window-complete: yes, ',
#  'n = 10, t = 1.00: L2 error on domain = 6.11e-12',
#  'output u^10 and u_ref^10',
#  '---[precice] \x1b Synchronize participants and close communication channels',
#  '']

# %%
stderr.split('\n')
# Out:
# ['']

# %%
stdout, stderr = process_2.communicate()

# %%
stdout.split('\n')
# Out:
# ['---[precice] \x1b This is preCICE version 2.3.0',
#  '---[precice] \x1b Revision info: no-info [Git failed/Not a repository]',
#  '---[precice] \x1b Configuration: Debug',
#  '---[precice] \x1b Configuring preCICE with configuration "/home/jovyan/fenics/../precice-config.xml"',
#  '---[precice] \x1b I am participant "Neumann"',
#  '---[precice] \x1b Setting up master communication to coupling partner/s',
#  '---[precice] \x1b Masters are connected',
#  '---[precice] \x1b Setting up preliminary slaves communication to coupling partner/s',
#  '---[precice] \x1b Receive global mesh Dirichlet-Mesh',
#  '---[precice] \x1b Prepare partition for mesh Neumann-Mesh',
#  '---[precice] \x1b Gather mesh Neumann-Mesh',
#  '---[precice] \x1b Send global mesh Neumann-Mesh',
#  '---[precice] \x1b Setting up slaves communication to coupling partner/s',
#  '---[precice] \x1b Slaves are connected',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, write-initial-data write-iteration-checkpoint ',
#  '---[precice] \x1b Compute "read" mapping from mesh "Dirichlet-Mesh" to mesh "Neumann-Mesh".',
#  '---[precice] \x1b Using tree-based preallocation for matrix C',
#  '---[precice] \x1b Using tree-based preallocation for matrix A',
#  '---[precice] \x1b Using rescaling. Solver converged after 5 of 10000 iterations due to sufficient relative convergence. Last residual norm: 2.70042e-13, limits: relative 3.16228e-09 (rtol 1e-09), absolute 1e-50, divergence 3.16228e+30(dtol 1e+30)',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  'output u^0 and u_ref^0',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.00e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 7.04e-02, limit = 1.00e-05, normalization = 1.09e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.27e-01, limit = 1.00e-05, normalization = 4.42e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.71e-02, limit = 1.00e-05, normalization = 1.08e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.03e-01, limit = 1.00e-05, normalization = 6.35e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.82e-03, limit = 1.00e-05, normalization = 1.06e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 4 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 3.78e-02, limit = 1.00e-05, normalization = 6.31e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.17e-03, limit = 1.00e-05, normalization = 1.06e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 5 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.40e-02, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.37e-04, limit = 1.00e-05, normalization = 1.06e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 6 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.78e-03, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.80e-05, limit = 1.00e-05, normalization = 1.06e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 7 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 2.36e-04, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 2.39e-06, limit = 1.00e-05, normalization = 1.06e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 8 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 3.14e-05, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 3.31e-07, limit = 1.00e-05, normalization = 1.06e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 9 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 4.20e-06, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 4.25e-08, limit = 1.00e-05, normalization = 1.06e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 1, t = 0.10: L2 error on domain = 5.58e-09',
#  'output u^1 and u_ref^1',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 6.79e-02, limit = 1.00e-05, normalization = 1.13e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 3.74e-09, limit = 1.00e-05, normalization = 1.09e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.68e-08, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 3.20e-09, limit = 1.00e-05, normalization = 1.09e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 2, t = 0.20: L2 error on domain = 3.83e-10',
#  'output u^2 and u_ref^2',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 6.56e-02, limit = 1.00e-05, normalization = 1.17e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.56e-11, limit = 1.00e-05, normalization = 1.13e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 4.79e-11, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 2.26e-11, limit = 1.00e-05, normalization = 1.13e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 4, time: 0.3 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 3, t = 0.30: L2 error on domain = 4.35e-11',
#  'output u^3 and u_ref^3',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 6.35e-02, limit = 1.00e-05, normalization = 1.21e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 4, time: 0.3 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 3.12e-11, limit = 1.00e-05, normalization = 1.17e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 4, time: 0.3 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 3.51e-11, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.45e-12, limit = 1.00e-05, normalization = 1.17e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 5, time: 0.4 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 4, t = 0.40: L2 error on domain = 1.42e-11',
#  'output u^4 and u_ref^4',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 6.15e-02, limit = 1.00e-05, normalization = 1.25e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 5, time: 0.4 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 2.70e-10, limit = 1.00e-05, normalization = 1.21e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 5, time: 0.4 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.46e-09, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 3.47e-10, limit = 1.00e-05, normalization = 1.21e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 6, time: 0.5 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 5, t = 0.50: L2 error on domain = 3.82e-11',
#  'output u^5 and u_ref^5',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.95e-02, limit = 1.00e-05, normalization = 1.29e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 6, time: 0.5 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 6.45e-11, limit = 1.00e-05, normalization = 1.25e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 6, time: 0.5 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.08e-09, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 3.75e-11, limit = 1.00e-05, normalization = 1.25e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 7, time: 0.6 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 6, t = 0.60: L2 error on domain = 5.94e-12',
#  'output u^6 and u_ref^6',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.78e-02, limit = 1.00e-05, normalization = 1.32e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 7, time: 0.6 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.24e-10, limit = 1.00e-05, normalization = 1.29e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 7, time: 0.6 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 3.49e-09, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.23e-10, limit = 1.00e-05, normalization = 1.29e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 8, time: 0.7 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 7, t = 0.70: L2 error on domain = 1.2e-11',
#  'output u^7 and u_ref^7',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.61e-02, limit = 1.00e-05, normalization = 1.36e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 8, time: 0.7 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 6.03e-11, limit = 1.00e-05, normalization = 1.33e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 8, time: 0.7 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.79e-10, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 4.09e-11, limit = 1.00e-05, normalization = 1.33e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 8, t = 0.80: L2 error on domain = 6.66e-12',
#  'output u^8 and u_ref^8',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.45e-02, limit = 1.00e-05, normalization = 1.40e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.04e-10, limit = 1.00e-05, normalization = 1.37e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.44e-09, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 2.73e-11, limit = 1.00e-05, normalization = 1.37e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint ',
#  'n = 9, t = 0.90: L2 error on domain = 6.3e-12',
#  'output u^9 and u_ref^9',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.03e+00, limit = 1.00e-05, normalization = 4.18e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 5.30e-02, limit = 1.00e-05, normalization = 1.45e+01, conv = false',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 2 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 6.83e-01, limit = 1.00e-05, normalization = 6.32e+00, conv = false',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 8.36e-11, limit = 1.00e-05, normalization = 1.41e+01, conv = true',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate',
#  '---[precice] \x1b iteration: 3 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint ',
#  'Solving linear variational problem.',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Flux" = 1.06e-09, limit = 1.00e-05, normalization = 6.32e+00, conv = true',
#  '---[precice] \x1b relative convergence measure: relative two-norm diff of data "Temperature" = 1.76e-11, limit = 1.00e-05, normalization = 1.41e+01, conv = true',
#  '---[precice] \x1b All converged',
#  '---[precice] \x1bWARNING: \x1b The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.',
#  '---[precice] \x1b Time window completed',
#  '---[precice] \x1b iteration: 1 of 100, time-window: 11, time: 1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: no, time-window-complete: yes, ',
#  'n = 10, t = 1.00: L2 error on domain = 4.41e-12',
#  'output u^10 and u_ref^10',
#  '---[precice] \x1b Synchronize participants and close communication channels',
#  '']

# %%
stderr.split('\n')
# Out:
# ['']
